# %% [markdown]
# ### Glean Data Scientist
#
# #### Project Summary
# --describe your project at a high level--
#
# The project follows the follow steps:
# * Step 1: Scope the Project and Gather Data
# * Step 2: Explore and Assess the Data
# * Step 3: Define the Data Model
# * Step 4: Run ETL to Model the Data
# * Step 5: Complete Project Write Up

# %%
# Do all imports and installs here
import pandas as pd, re
import numpy as np 

import configparser
from datetime import datetime
import os

from pyspark.context import SparkContext
from pyspark.sql import SparkSession
from pyspark.sql.functions import udf, col
from pyspark.sql.functions import year, month, dayofmonth, hour, weekofyear, date_format, months_between


pd.options.display.max_colwidth = 1000

# %% [markdown]
# **Note**: Set to path of data sources to process.

# %%
invoice_filename = "./invoice.csv"
line_item_filename = "./line_item.csv"

# %%
# configure aws credentials
#os.environ['AWS_ACCESS_KEY_ID']=''
#os.environ['AWS_SECRET_ACCESS_KEY']=''
os.environ['PYSPARK_PYTHON'] = '/Users/kathryn/opt/anaconda3/bin/python'
os.environ['PYSPARK_DRIVER_PYTHON'] = '/Users/kathryn/opt/anaconda3/bin/python'

# %%
# Create Spark Session for Data Process
spark = SparkSession.builder\
.config("spark.jars.packages","saurfang:spark-sas7bdat:3.0.0-s_2.12,org.apache.hadoop:hadoop-aws:2.7.0")\
.enableHiveSupport().getOrCreate()

#.config("spark.executor.extraJavaOptions", "-Dcom.amazonaws.services.s3.enableV4=true")\
#.config("spark.hadoop.fs.s3a.endpoint", "s3.us-east-2.amazonaws.com")\

# %% [markdown]
# ### Task and Data
#
# Using two input CSVs, create a Spark Scala/PySpark/Dask application (you can use any other distributed framework for data processing) which will process input data and create and store a new CSV with insights (what we call gleans).
#
# The app with the code should be pushed to GitHub/GitLab or any other git based platform.
#
# #### Input CSVs structure:
#
# - invoice
#  	invoice_id - Invoice UUID
# 	invoice_date - Issue date
# 	due_date - Due date
# 	period_start_date - Start date (if any) of service dates that invoice covers
# 	period_end_date - End date (if any) of service dates that invoice covers
# 	total_amount - Billed Amount
# 	canonical_vendor_id - Vendor UUID
#
# - line_item
#  	invoice_id - Invoice UUID
# 	line_item_id - Raw Line Item UUID
# 	period_start_date - Start date (if any) of service dates that raw line item covers
# 	period_end_date - End date (if any) of service dates that raw line item covers
# 	total_amount - Billed Amount
# 	canonical_line_item_id - Canonical line item UUID
#
#
# #### Output CSV structure:
#
# 	glean_id - Glean UUID
# 	glean_date - Date when glean was triggered
# 	glean_text - Glean Text
# 	glean_type - Enum (vendor_not_seen_in_a_while, accrual_alert, large_month_increase_mtd, no_invoice_received)
# 	glean_location - Enum (invoice or vendor)
# 	invoice_id - Invoice UUID
# 	canonical_vendor_id - Vendor UUID
#
# #### Additional notes:
# - 1:M relationship between invoice and line_item
# - 1:M relationship between line_item_id and canonical_line_item_id (i.e. different raw line items can be mapped to a single canonical line item)

# %% [markdown]
# #### Gleans (insights) to be generated and backfilled in the past:
#
# ##### vendor_not_seen_in_a_while
#
# 	logic:
# 	1) don't trigger if invoice received from the vendor for the first time
# 	2) trigger if invoice received from the vendor and it's > 90 days since last `invoice_date`
#
# 	glean_text (text of the glean to be created):
# 		First new bill in [count_of_months_since_last_invoice] months from vendor [canonical_vendor_id]
#
# 	glean_location:
# 		invoice (this glean should be created on an invoice level)
#
# ##### accrual_alert
#
# 	logic:
# 	1) trigger if `period_end_date` for invoice or any line item > 90 days after `invoice_date`
# 	   If there are multiple end dates, pick the last one.
#
# 	glean_text (text of the glean to be created):
# 		Line items from vendor [canonical_vendor_id] in this invoice cover future periods (through [period_end_date])
#
# 	glean_location:
# 		invoice (this glean should be created on an invoice level)
#
# ##### large_month_increase_mtd
#
# 	logic:
# 	1) trigger if monthly spend > $10K and it increased > 50% of average spend over last 12 months. If monthly spend is less than $10K, > 200%. If less than $1K, > 500%. If less than $100, don't trigger the glean. Spend is sum of invoice `total_amount`.
#
#
# 	glean_text (text of the glean to be created):
# 		Monthly spend with [canonical_vendor_id] is $x (x%) higher than average
#
# 	glean_location:
# 		vendor (this glean should be created on a vendor level)
#
# ##### no_invoice_received
#
# 	logic:
# 	1) trigger if vendor sends invoice(s) either on MONTHLY basis (1 or more per month) or QUARTERLY basis (1 per quarter).
#
# 		1.1) MONTHLY case: trigger if there were 3 consecutive months with invoices received from vendor but there are no invoices received in current month.
# 			 Start triggering the glean from the day when vendor usually sends the invoice (you need to count day frequency). Keep triggering the glean till the end of the current month or until the day when new invoice received.
# 			 If there are multiple days based on frequency count, pick the earliest one.
#
# 		1.2) QUARTERLY case: trigger if there were 2 consecutive quarters with invoices received from vendor but there are no invoices received in current quarter.
# 			 Start triggering the glean from the day when vendor usually sends the invoice (you need to count day frequency). Keep triggering the glean till the end of the current month of the quarter or until the day when new invoice received.
# 			 If there are multiple days based on frequency count, pick the earliest one.
#
#
# 	glean_text (text of the glean to be created):
# 		[canonical_vendor_id] generally charges between on [most_frequent_day_number] day of each month invoices are sent. On [date], an invoice from [canonical_vendor_id] has not been received
#
# 	glean_location:
# 		vendor (this glean should be created on a vendor level)

# %%
invoice = spark.read.option("delimiter",",").option("header",True).csv(invoice_filename)

# %%
invoice.printSchema()
# Out:
# root
#  |-- invoice_id: string (nullable = true)
#  |-- invoice_date: string (nullable = true)
#  |-- due_date: string (nullable = true)
#  |-- period_start_date: string (nullable = true)
#  |-- period_end_date: string (nullable = true)
#  |-- total_amount: string (nullable = true)
#  |-- canonical_vendor_id: string (nullable = true)

# %%
invoice.select("invoice_id").distinct().count()
# Out:
# 1633

# %%
line_item = spark.read.option("delimiter",",").option("header",True).csv(line_item_filename)

# %%
line_item.printSchema()
# Out:
# root
#  |-- invoice_id: string (nullable = true)
#  |-- line_item_id: string (nullable = true)
#  |-- period_start_date: string (nullable = true)
#  |-- period_end_date: string (nullable = true)
#  |-- total_amount: string (nullable = true)
#  |-- canonical_line_item_id: string (nullable = true)

# %%
# Create view for Spark SQL

invoice.createOrReplaceTempView("invoice") 
line_item.createOrReplaceTempView("line_item")

# %%
vendor_not_seen_in_a_while_gleans = spark.sql("""
select 
    uuid() as glean_id,
    invoice_date as glean_date,
--    lag_invoice_date,
    concat(
        'First new bill in ', 
        CAST(months_between(invoice_date, lag_invoice_date) as int),
        ' months from vendor ', 
        canonical_vendor_id
     ) 
as glean_text,     
    'vendor_not_seen_in_a_while' as glean_type,
    "invoice" as glean_location, 
    invoice_id,
    canonical_vendor_id
from (
    select 
        *,
        LAG(i.invoice_date, 1, '') OVER (PARTITION BY i.canonical_vendor_id ORDER BY i.invoice_date) 
            as lag_invoice_date
    from invoice i
) invoice_with_lag 
where datediff(invoice_date, lag_invoice_date) > 90

""")
vendor_not_seen_in_a_while_gleans.limit(1).toPandas().T
# Out:
#                                                                                                0
# glean_id                                                    c746106d-47bd-42b3-b400-7e553fc848da
# glean_date                                                                            2020-01-20
# glean_text           First new bill in 4 months from vendor c753ab1a-cd7b-4968-9a25-0f0471b0c882
# glean_type                                                            vendor_not_seen_in_a_while
# glean_location                                                                           invoice
# invoice_id                                                  e27451bb-b2eb-45e1-9b96-83c2f5399bcf
# canonical_vendor_id                                         c753ab1a-cd7b-4968-9a25-0f0471b0c882

# %%
Line items from vendor [canonical_vendor_id] in this invoice cover future periods (through [period_end_date])

# %%
       
CAST(months_between(LEAD(i.invoice_date, 1, '') OVER (PARTITION BY i.canonical_vendor_id ORDER BY i.invoice_date), i.invoice_date)  as int),
' months from vendor ', i.canonical_vendor_id)

# %%
spark.sql("select canonical_vendor_id,count(*) from invoice group by canonical_vendor_id").registerTempTable("vendor_invoice_count")

# %%
mylimit = 10
spark.sql("select * from vendor_invoice_count").limit(mylimit).toPandas()

# %%
dir(invoice.groupby("canonical_vendor_id"))

# %% [markdown]
# ## accrual_alert
#
# logic:
#
# 1) trigger if `period_end_date` for invoice or any line item > 90 days after `invoice_date`
#    If there are multiple end dates, pick the last one.
#
# glean_text (text of the glean to be created):
#     Line items from vendor [canonical_vendor_id] in this invoice cover future periods (through [period_end_date])
#
# glean_location:
#     invoice (this glean should be created on an invoice level)

# %% [markdown]
# - glean_id - Glean UUID
# - glean_date - Date when glean was triggered
# - glean_text - Glean Text
# - glean_type - Enum (vendor_not_seen_in_a_while, accrual_alert, large_month_increase_mtd, no_invoice_received)
# - glean_location - Enum (invoice or vendor)
# - invoice_id - Invoice UUID
# - canonical_vendor_id - Vendor UUID

# %%
accural_alert_gleans = spark.sql("""
    select
        uuid() as glean_id,
        invoice_date as glean_date,
        concat(
            'Line items from vendor ', 
            canonical_vendor_id,
            'in this invoice cover future periods (through ', 
            max_period_end_date, ')'
        ) 
        as glean_text,     
        'accrual_alert' as glean_type,
        "invoice" as glean_location, 
        invoice_id,
        canonical_vendor_id
    from (
        select 
            i.invoice_id,
            i.invoice_date, 
            i.canonical_vendor_id, 
            max(l.period_end_date) as max_period_end_date
        from invoice i 
        left join line_item l 
        on i.invoice_id = l.invoice_id   
        group by 
            i.invoice_id,
            i.invoice_date, 
            i.canonical_vendor_id
    ) vendor_and_line    
    where datediff(max_period_end_date, invoice_date) > 90
""")

accural_alert_gleans.limit(1).toPandas().T
# Out:
#                                                                                                                                         0
# glean_id                                                                                             bfd8ab3b-31d8-4bd9-8c44-8397a2c8de0e
# glean_date                                                                                                                     2020-07-22
# glean_text           Line items from vendor 29565c48-872e-4a2a-a582-00dcdac573a1in this invoice cover future periods (through 2021-07-22)
# glean_type                                                                                                                  accrual_alert
# glean_location                                                                                                                    invoice
# invoice_id                                                                                           100360f5-49ff-4ba7-8d1e-a3b8c4e132a7
# canonical_vendor_id                                                                                  29565c48-872e-4a2a-a582-00dcdac573a1

# %%
# large_month_increase_mtd
spark.sql("""
        uuid() as glean_id,
        invoice_date as glean_date,
        concat(
            'text of the glean to be created):Monthly spend with ',
            canonical_vendor_id,
            'is $x (x%) higher than average'
        ) 
        as glean_text,     
        'large_month_increase_mtd' as glean_type,
        "invoice" as glean_location, 
        invoice_id,
        canonical_vendor_id
        from
        
        
        
        (
        SELECT 
         i.canonical_vendor_id, 
         sum(i.total_amount) as monthly_spend,
         cast(month(i.invoice_date) as int) as month, 
         cast(year(i.invoice_date) as int) as year,
         
         cast(month(i.invoice_date) as int) +
         cast(year(i.invoice_date) as int) * 12 as monthnum
FROM invoice i
GROUP BY i.canonical_vendor_id,
         month(i.invoice_date), 
         year(i.invoice_date)
ORDER BY cast(month(i.invoice_date) as int),
         year(i.invoice_date)
         )
"""
          
avg(mt) OVER (partition by date order by )

# %%
#1) trigger if monthly spend > $10K and it increased > 50% of average spend over last 12 months. 
#If monthly spend is less than $10K, > 200%. If less than $1K, > 500%. 
#If less than $100, don't trigger the glean. Spend is sum of invoice `total_amount`.

# %%
spark.sql("""
WITH monthly_total as (
        SELECT 
         i.canonical_vendor_id, 
         sum(i.total_amount) as monthly_spend,
         cast(month(i.invoice_date) as int) as month, 
         cast(year(i.invoice_date) as int) as year,
         
         cast(month(i.invoice_date) as int) +
         cast(year(i.invoice_date) as int) * 12 as monthnum
FROM invoice i
GROUP BY i.canonical_vendor_id,
         month(i.invoice_date), 
         year(i.invoice_date)
ORDER BY year(i.invoice_date),
         cast(month(i.invoice_date) as int)
         
)
SELECT 
-- case when 
--     (inv.total_amount between 100 and 1000) and 
-- (i.total_amount - 
*,
(AVG(monthly_spend) 
    OVER (PARTITION BY monthly_total.canonical_vendor_id
    ORDER BY monthly_total.monthnum ROWS BETWEEN 12 PRECEDING AND CURRENT ROW))                                
     
FROM
    monthly_total

""").limit(50).toPandas()
# Out:
#                      canonical_vendor_id  monthly_spend  month  year  \
# 0   c753ab1a-cd7b-4968-9a25-0f0471b0c882         377.69      2  2019
# 1   c753ab1a-cd7b-4968-9a25-0f0471b0c882         377.69      4  2019
# 2   c753ab1a-cd7b-4968-9a25-0f0471b0c882         612.42      5  2019
# 3   c753ab1a-cd7b-4968-9a25-0f0471b0c882         633.17      6  2019
# 4   c753ab1a-cd7b-4968-9a25-0f0471b0c882         653.58      7  2019
# 5   c753ab1a-cd7b-4968-9a25-0f0471b0c882         690.06      8  2019
# 6   c753ab1a-cd7b-4968-9a25-0f0471b0c882         765.20      9  2019
# 7   c753ab1a-cd7b-4968-9a25-0f0471b0c882        2833.08      1  2020
# 8   c753ab1a-cd7b-4968-9a25-0f0471b0c882        2905.04      2  2020
# 9   c753ab1a-cd7b-4968-9a25-0f0471b0c882       45059.31      3  2020
# 10  c753ab1a-cd7b-4968-9a25-0f0471b0c882        4381.52      4  2020
# 11  c753ab1a-cd7b-4968-9a25-0f0471b0c882        4263.94      5  2020
# 12  c753ab1a-cd7b-4968-9a25-0f0471b0c882        4859.28      6  2020
# 13  c753ab1a-cd7b-4968-9a25-0f0471b0c882        5276.70      7  2020
# 14  c753ab1a-cd7b-4968-9a25-0f0471b0c882         519.49      8  2020
# 15  c753ab1a-cd7b-4968-9a25-0f0471b0c882          52.42      9  2020
# 16  c753ab1a-cd7b-4968-9a25-0f0471b0c882          52.46     10  2020
# 17  c753ab1a-cd7b-4968-9a25-0f0471b0c882        6458.31     11  2020
# 18  c753ab1a-cd7b-4968-9a25-0f0471b0c882         964.77     12  2020
# 19  561dd6da-890f-44c7-b62d-346d56951dad        6452.50      2  2020
# 20  982c44ce-08fc-4abb-8191-e80dd5cb7782        2177.50      5  2020
# 21  0d41b0c0-dd27-4c32-909d-a190744e747b        1412.24      1  2020
# 22  0d41b0c0-dd27-4c32-909d-a190744e747b        4850.39      9  2020
# 23  9be41a38-e810-48f6-8149-d9b19dee73e8        6581.50      5  2019
# 24  9be41a38-e810-48f6-8149-d9b19dee73e8        4223.26      6  2019
# 25  9be41a38-e810-48f6-8149-d9b19dee73e8        4123.93      2  2020
# 26  9be41a38-e810-48f6-8149-d9b19dee73e8        2838.49      4  2020
# 27  9be41a38-e810-48f6-8149-d9b19dee73e8        7944.54      5  2020
# 28  9be41a38-e810-48f6-8149-d9b19dee73e8        2582.58      6  2020
# 29  9be41a38-e810-48f6-8149-d9b19dee73e8        1157.53      7  2020
# 30  9be41a38-e810-48f6-8149-d9b19dee73e8          77.60      8  2020
# 31  9be41a38-e810-48f6-8149-d9b19dee73e8        2433.45      9  2020
# 32  9be41a38-e810-48f6-8149-d9b19dee73e8        5187.34     10  2020
# 33  9be41a38-e810-48f6-8149-d9b19dee73e8        2779.29     11  2020
# 34  9be41a38-e810-48f6-8149-d9b19dee73e8        3681.88     12  2020
# 35  bd81a118-4b34-4c01-821a-6413f32af010          96.84      3  2019
# 36  bd81a118-4b34-4c01-821a-6413f32af010          93.24      4  2019
# 37  bd81a118-4b34-4c01-821a-6413f32af010          91.56      6  2019
# 38  bd81a118-4b34-4c01-821a-6413f32af010         130.04      7  2019
# 39  3a64161d-30c9-41b8-85e7-910b891e6520       13609.38      3  2020
# 40  3a64161d-30c9-41b8-85e7-910b891e6520       13609.38      6  2020
# 41  3bf52d08-23c4-4af5-9c42-7e801cba7836         819.18     11  2020
# 42  8b66c60d-af66-4e46-b28c-45ead7f13b23        1861.44      5  2019
# 43  e00750f3-4c40-41ee-a156-78989ea78b19         161.69     10  2020
# 44  089685a6-ecec-44ab-bfdf-b2ccb5182382       10332.69      3  2020
# 45  089685a6-ecec-44ab-bfdf-b2ccb5182382       33370.18      8  2020
# 46  335fd6c2-e48b-4a71-96c3-71efae5ffe30         635.09      5  2019
# 47  335fd6c2-e48b-4a71-96c3-71efae5ffe30        1534.65      6  2019
# 48  335fd6c2-e48b-4a71-96c3-71efae5ffe30        1830.73      7  2019
# 49  335fd6c2-e48b-4a71-96c3-71efae5ffe30         261.30      8  2019
#
#     monthnum  \
# 0      24230
# 1      24232
# 2      24233
# 3      24234
# 4      24235
# 5      24236
# 6      24237
# 7      24241
# 8      24242
# 9      24243
# 10     24244
# 11     24245
# 12     24246
# 13     24247
# 14     24248
# 15     24249
# 16     24250
# 17     24251
# 18     24252
# 19     24242
# 20     24245
# 21     24241
# 22     24249
# 23     24233
# 24     24234
# 25     24242
# 26     24244
# 27     24245
# 28     24246
# 29     24247
# 30     24248
# 31     24249
# 32     24250
# 33     24251
# 34     24252
# 35     24231
# 36     24232
# 37     24234
# 38     24235
# 39     24243
# 40     24246
# 41     24251
# 42     24233
# 43     24250
# 44     24243
# 45     24248
# 46     24233
# 47     24234
# 48     24235
# 49     24236
#
#     avg(monthly_spend) OVER (PARTITION BY canonical_vendor_id ORDER BY monthnum ASC NULLS FIRST ROWS BETWEEN 12 PRECEDING AND CURRENT ROW)
# 0                                                                                                                               377.690000
# 1                                                                                                                               377.690000
# 2                                                                                                                               455.933333
# 3                                                                                                                               500.242500
# 4                                                                                                                               530.910000
# 5                                                                                                                               557.435000
# 6                                                                                                                               587.115714
# 7                                                                                                                               867.861250
# 8                                                                                                                              1094.214444
# 9                                                                                                                              5490.724000
# 10                                                                                                                             5389.887273
# 11                                                                                                                             5296.058333
# 12                                                                                                                             5262.460000
# 13                                                                                                                             5639.306923
# 14                                                                                                                             5650.214615
# 15                                                                                                                             5607.137692
# 16                                                                                                                             5562.467692
# 17                                                                                                                             6008.985385
# 18                                                                                                                             6030.116923
# 19                                                                                                                             6452.500000
# 20                                                                                                                             2177.500000
# 21                                                                                                                             1412.240000
# 22                                                                                                                             3131.315000
# 23                                                                                                                             6581.500000
# 24                                                                                                                             5402.380000
# 25                                                                                                                             4976.230000
# 26                                                                                                                             4441.795000
# 27                                                                                                                             5142.344000
# 28                                                                                                                             4715.716667
# 29                                                                                                                             4207.404286
# 30                                                                                                                             3691.178750
# 31                                                                                                                             3551.431111
# 32                                                                                                                             3715.022000
# 33                                                                                                                             3629.955455
# 34                                                                                                                             3634.282500
# 35                                                                                                                               96.840000
# 36                                                                                                                               95.040000
# 37                                                                                                                               93.880000
# 38                                                                                                                              102.920000
# 39                                                                                                                            13609.380000
# 40                                                                                                                            13609.380000
# 41                                                                                                                              819.180000
# 42                                                                                                                             1861.440000
# 43                                                                                                                              161.690000
# 44                                                                                                                            10332.690000
# 45                                                                                                                            21851.435000
# 46                                                                                                                              635.090000
# 47                                                                                                                             1084.870000
# 48                                                                                                                             1333.490000
# 49                                                                                                                             1065.442500

# %%
#Join Method

monthly_spend_vs_prior_avg = spark.sql("""
WITH monthly_total as (
        SELECT 
         i.canonical_vendor_id, 
         sum(i.total_amount) as monthly_spend,
         max(i.invoice_date) as max_invoice_date,
         cast(month(i.invoice_date) as int) as month, 
         cast(year(i.invoice_date) as int) as year,         
         cast(month(i.invoice_date) as int) +
         cast(year(i.invoice_date) as int) * 12 as monthnum
FROM invoice i
GROUP BY i.canonical_vendor_id,
         month(i.invoice_date), 
         year(i.invoice_date)
ORDER BY year(i.invoice_date),
         cast(month(i.invoice_date) as int)
         
)
SELECT 
    monthly_total.monthnum,
    monthly_total.canonical_vendor_id,
    monthly_total.monthly_spend,
    monthly_total.max_invoice_date,
    AVG(preceding_months.monthly_spend) as TTM_avg,
    COUNT(preceding_months.monthly_spend) as average_count
FROM
    monthly_total
LEFT JOIN
    monthly_total preceding_months ON (
        preceding_months.monthnum BETWEEN monthly_total.monthnum - 12 AND monthly_total.monthnum - 1
        AND preceding_months.canonical_vendor_id = monthly_total.canonical_vendor_id
    ) 

GROUP BY
    monthly_total.monthly_spend,
    monthly_total.monthnum, 
    monthly_total.canonical_vendor_id,
    monthly_total.max_invoice_date
ORDER BY
    monthly_total.canonical_vendor_id,
    monthly_total.monthnum
""")
monthly_spend_vs_prior_avg.registerTempTable("monthly_spend_vs_prior_avg")

monthly_spend_vs_prior_avg.limit(10).toPandas()
# Out:
#    monthnum                   canonical_vendor_id  monthly_spend  \
# 0     24238  009f387e-d8d7-4d34-b14b-ce62c84f8aef          54.44
# 1     24239  009f387e-d8d7-4d34-b14b-ce62c84f8aef          54.44
# 2     24240  009f387e-d8d7-4d34-b14b-ce62c84f8aef          54.44
# 3     24241  009f387e-d8d7-4d34-b14b-ce62c84f8aef          17.94
# 4     24243  009f387e-d8d7-4d34-b14b-ce62c84f8aef          82.14
# 5     24244  009f387e-d8d7-4d34-b14b-ce62c84f8aef          82.49
# 6     24245  009f387e-d8d7-4d34-b14b-ce62c84f8aef         135.87
# 7     24246  009f387e-d8d7-4d34-b14b-ce62c84f8aef         136.46
# 8     24247  009f387e-d8d7-4d34-b14b-ce62c84f8aef         136.46
# 9     24248  009f387e-d8d7-4d34-b14b-ce62c84f8aef         136.22
#
#   max_invoice_date    TTM_avg  average_count
# 0       2019-10-07        NaN              0
# 1       2019-11-07  54.440000              1
# 2       2019-12-07  54.440000              2
# 3       2020-01-07  54.440000              3
# 4       2020-03-07  45.315000              4
# 5       2020-04-07  52.680000              5
# 6       2020-05-07  57.648333              6
# 7       2020-06-08  68.822857              7
# 8       2020-07-07  77.277500              8
# 9       2020-08-08  83.853333              9

# %%
mtd_increase_glean = spark.sql("""
select 
        uuid() as glean_id,
        max_invoice_date as glean_date,
        concat(
            'Monthly spend with ',
            canonical_vendor_id,
            'is $x (x%) higher than average'
        ) 
        as glean_text,     
        'large_month_increase_mtd' as glean_type,
        'vendor' as glean_location, 
        null as invoice_id,
        canonical_vendor_id
from monthly_spend_vs_prior_avg 
WHERE 
    (monthly_spend between 100 and 1000 and monthly_spend /TTM_avg > 6)
    or (monthly_spend between 1001 and 10000 and monthly_spend /TTM_avg > 3)
    or (monthly_spend > 10001 and monthly_spend /TTM_avg > 1.5)
""").cache()
mtd_increase_glean.limit(5).toPandas()
# Out:
#                                glean_id  glean_date  \
# 0  4eaae2d1-3d79-488b-ba81-8966be023afc  2020-06-30
# 1  9ad24a75-7347-4dbd-935a-2b9c2d2868e1  2020-08-01
# 2  f15a0df9-61ee-4fee-b7b2-63cb09eaf2fb  2020-09-21
# 3  f6680c3f-9908-41c1-8e36-2e88b4769afb  2020-07-21
# 4  6d2cb486-727b-4283-8fb6-01983ad0a56b  2020-10-13
#
#                                                                               glean_text  \
# 0  Monthly spend with 014deb41-8f37-4f50-81b2-856e7fea015eis $x (x%) higher than average
# 1  Monthly spend with 089685a6-ecec-44ab-bfdf-b2ccb5182382is $x (x%) higher than average
# 2  Monthly spend with 0d41b0c0-dd27-4c32-909d-a190744e747bis $x (x%) higher than average
# 3  Monthly spend with 0fe5f1a4-849a-4e7c-bb11-00e5e9d6cec0is $x (x%) higher than average
# 4  Monthly spend with 0fe5f1a4-849a-4e7c-bb11-00e5e9d6cec0is $x (x%) higher than average
#
#                  glean_type glean_location invoice_id  \
# 0  large_month_increase_mtd         vendor       None
# 1  large_month_increase_mtd         vendor       None
# 2  large_month_increase_mtd         vendor       None
# 3  large_month_increase_mtd         vendor       None
# 4  large_month_increase_mtd         vendor       None
#
#                     canonical_vendor_id
# 0  014deb41-8f37-4f50-81b2-856e7fea015e
# 1  089685a6-ecec-44ab-bfdf-b2ccb5182382
# 2  0d41b0c0-dd27-4c32-909d-a190744e747b
# 3  0fe5f1a4-849a-4e7c-bb11-00e5e9d6cec0
# 4  0fe5f1a4-849a-4e7c-bb11-00e5e9d6cec0

# %% [markdown]
# ## Average Monthly Validation
#
# Validate the distribution of count of non-empty months in the preceding 12 months.

# %%
month_count_distribution = (
    monthly_spend_vs_prior_avg
    .groupby("average_count").count()
    .sort("average_count")
).toPandas()
month_count_distribution.set_index("average_count", inplace=True)
month_count_distribution['count']
# Out:
# average_count
# 0     276
# 1     155
# 2     126
# 3     107
# 4      83
# 5      86
# 6      69
# 7      62
# 8      44
# 9      43
# 10     24
# 11     43
# 12     15
# Name: count, dtype: int64

# %%
month_count_distribution['count'].plot(kind="bar")

# %%
spark.sql("""
SELECT 
         i.canonical_vendor_id, 
         sum(i.total_amount) as monthly_spend,
         cast(month(i.invoice_date) as int) as month, 
         cast(year(i.invoice_date) as int) as year,
         
         cast(month(i.invoice_date) as int) +
         cast(year(i.invoice_date) as int) * 12 as monthnum
FROM invoice i
GROUP BY i.canonical_vendor_id,
         month(i.invoice_date), 
         year(i.invoice_date)
ORDER BY year(i.invoice_date),
         cast(month(i.invoice_date) as int)
""").limit(10).toPandas()
# Out:
#                     canonical_vendor_id  monthly_spend  month    year  \
# 0  d4ecb721-41d7-43ed-b78e-a09e50955559           4.40    NaN     NaN
# 1  8b051cbe-436d-4504-bf25-5c52af34c698        2665.14    NaN     NaN
# 2  3629f0a6-158e-4027-92c7-26806c316bc2       39948.33    4.0  2018.0
# 3  8b542ecf-98dc-4633-8aa9-368bbd83fff3          88.19    4.0  2018.0
# 4  f4fe1983-adde-416b-88d2-be837908b745       53000.00    5.0  2018.0
# 5  cbbee2fb-061a-40b0-ad51-94a8d286a0a4       45413.94   10.0  2018.0
# 6  10f69fbc-678c-4af1-8894-4f176c2b276c        9511.24   11.0  2018.0
# 7  3d2e310c-a166-42e6-a6d8-fe28f38acbd7       40704.00   11.0  2018.0
# 8  cbbee2fb-061a-40b0-ad51-94a8d286a0a4        2436.02   12.0  2018.0
# 9  e7f597e5-0d7b-4192-a7d8-60d0b3b4115e       20786.88   12.0  2018.0
#
#    monthnum
# 0       NaN
# 1       NaN
# 2   24220.0
# 3   24220.0
# 4   24221.0
# 5   24226.0
# 6   24227.0
# 7   24227.0
# 8   24228.0
# 9   24228.0

# %%
spark.sql("""
SELECT 
         i.canonical_vendor_id, 
         sum(i.total_amount) as monthly_spend,
         cast(month(i.invoice_date) as int) as month, 
         cast(year(i.invoice_date) as int) as year,
         
         cast(month(i.invoice_date) as int) +
         cast(year(i.invoice_date) as int) * 12 as monthnum
FROM invoice i
GROUP BY i.canonical_vendor_id,
         month(i.invoice_date), 
         year(i.invoice_date)
ORDER BY cast(month(i.invoice_date) as int),
         year(i.invoice_date)
""").limit(5).toPandas()
# Out:
#                     canonical_vendor_id  monthly_spend  month    year  \
# 0  8b051cbe-436d-4504-bf25-5c52af34c698        2665.14    NaN     NaN
# 1  d4ecb721-41d7-43ed-b78e-a09e50955559           4.40    NaN     NaN
# 2  153ec8ce-be54-4776-9e21-78e27dc6c507       16333.66    1.0  2019.0
# 3  af77b10e-791e-4b43-a1eb-116e3e4bc4ec         112.74    1.0  2019.0
# 4  35c065e2-87fa-4c57-b0b8-c7843433b791         143.06    1.0  2019.0
#
#    monthnum
# 0       NaN
# 1       NaN
# 2   24229.0
# 3   24229.0
# 4   24229.0

# %%
CASE WHEN 
COUNT(*) OVER (ORDER BY Company, [Revenue Year] ROWS BETWEEN UNBOUNDED PRECEDING AND CURRENT ROW) > 2
THEN AVG([Revenue Amount]) OVER (ORDER BY Company,[Revenue Year] ROWS BETWEEN 2 PRECEDING AND CURRENT ROW
ELSE NULL
END ThreeMonthRunningAvg
                                 
case when (i.total_amount between 100 and 1000) and 
(i.total_amount - (AVG([i.total_amount]) OVER (ORDER BY Company,[Revenue Year] ROWS BETWEEN 2 PRECEDING AND CURRENT ROW))                                
                                                     
                                                     
(SELECT i.canonical_vendor_id, i.invoice_date, i.total_amount
SELECT i.canonical_vendor_id, sum(i.total_amount),
       month(convert(i.invoice_date, cast(monthnumber as nvarchar(10))+'01')) as Month, 
       year(convert(i.invoice_date, cast(monthnumber as nvarchar(10))+'01')) as Year
FROM invoice i
GROUP BY i.canonical_vendor_id,
         MONTH(convert(i.invoice_date,cast(monthnumber as nvarchar(10))+'01')),
         YEAR(convert(i.invoice_date,cast(monthnumber as nvarchar(10))+'01')) 
) as ia

# %%
# no_invoice_received
spark.sql("""
select 
invoice_id() over (order by “monotonically_increasing_id”) as glean_id, 
glean_date,
#glean_text,
#glean_type,
case when (LAG(invoice_date, 1) OVER (ORDER BY campaign, canonical_vendor_id)) > 90 and is not null 
end as "glean_type",
DATEDIFF(date, l.period_end_date, i.invoice_date) > 90 
then 'vendor_not_seen_in_a_while' end as 'glean_type', 
# glean_location(invoice), 
l.canonical_line_item_id
from invoice i inner left join line_item l on i.invoice_id = l.line_item
"""

# %% [markdown]
# ### Step 2: Explore and Assess the Data
# #### Explore the Data
# Analyzing dataset with the schema and variables in the data.
#
# #### Cleaning Steps
# Drop duplicates for i94 dataset (if birthyear, occupation, gender, visatype, port, state is the same)

# %%
i94_apr16 = i94_apr16.select("cicid","i94port","arrdate","biryear","gender","occup","visatype")

# %%
# Present Data Schema before cleaning data
i94_apr16.printSchema()
USCity.printSchema()

# %%
i94_apr16.count()

# %%
i94_apr16.select("cicid").distinct().count()

# %%
i94_apr16.toPandas()

# %%
ports = i94_apr16.groupby("i94port", "i94addr").count().toPandas()

# %%
ports.groupby("i94port")['i94addr'].apply(list)

# %%
fraction_df = pd.merge(
    ports.groupby('i94port')['count'].sum(),
    ports,
    left_index=True,
    right_on=['i94port']
)
fraction_df['frac'] = fraction_df['count_y'] / fraction_df['count_x']
fraction_df.sort_values('frac')

# %%
fraction_df[fraction_df.i94port == 'NYC'].sort_values('frac')

# %%
(
    i94_apr16
    .filter(i94_apr16.i94port == 'NYC')
    .filter(i94_apr16.i94addr == 'CA')
    .limit(5)
).toPandas().T

# %%
i94_apr16\
  .groupby(['i94cit', 'i94addr'])\
  .count().orderBy('i94cit')\
  .limit(50).toPandas()

# %%
fraction_df.groupby(fraction_df.frac > 0.9).count_y.sum()

# %%
fraction_df[fraction_df.frac < 1]['frac'].hist(bins=100)

# %% [markdown]
# ### Step 3: Define the Data Model
# #### 3.1 Conceptual Data Model
#
# Map out the conceptual data model and explain why you chose that model
#
# #### 3.2 Mapping Out Data Pipelines
# List the steps necessary to pipeline the data into the chosen data model

# %% [markdown]
# ### Step 4: Run Pipelines to Model the Data
# #### 4.1 Create the data model
# Build the data pipelines to create the data model.

# %%
# Write code here

# %%
i94_apr16.createOrReplaceTempView("i94_table_data")
city_state_code.createOrReplaceTempView("city_code_data")
state_code.createOrReplaceTempView("state_code_data")

# %%
def process_traveler_entry_data(spark, output_data):
    """
    This function load data to S3
    """
    
    #create table
    traveler_entry_table = spark.sql("""
                           SELECT
                           cicid as id,
                           i94port as city_code, 
                           arrdate as arrive
                           FROM i94_table_data
                           """)
    
    # write table to parquet files
    traveler_entry_table.write.mode('overwrite').parquet(output_data+'traveler_entry_table/')

# %%
def process_visitors_data(spark, output_data):
    """
    This function load data to S3
    """
    
    #create table
    visitors_table = spark.sql("""
                               SELECT 
                               cicid as id,
                               biryear as birthyear,
                               gender,
                               occup as occupation, 
                               visatype
                               FROM i94_table_data
                               """)
    
    # write table to parquet files
    visitors_table.write.mode('overwrite').parquet(output_data+'visitors_table/')

# %%
def process_city_code_data(spark, output_data):
    """
    This function load data to S3
    """
    
    #create table
    city_code_table = spark.sql("""
                       SELECT
                       c.port_code as city_code,
                       c.city as city_name,
                       c.state as state_code,
                       s.state_name
                       FROM city_code_data c left join state_code_data s on c.state = s.state_code 
                       """)
    
    # write table to parquet files
    city_code_table.repartition(4).write.mode('overwrite').parquet(output_data+'city_code_table/')

# %%
def main():
    output_data = "s3a://flaaffy-spark/travel_v4/"
    
    #process_traveler_entry_data(spark, output_data)   
    #process_visitors_data(spark, output_data)  
    process_city_code_data(spark, output_data)    


if __name__ == "__main__":
    main()

# %%
cityp1=spark.read.parquet("s3a://flaaffy-spark/travel_v3/city_code_table")

# %%
cityp1.count()

# %% [markdown]
# #### 4.2 Data Quality Checks
# Explain the data quality checks you'll perform to ensure the pipeline ran as expected. These could include:
#  * Integrity constraints on the relational database (e.g., unique key, data type, etc.)
#  * Unit tests for the scripts to ensure they are doing the right thing
#  * Source/Count checks to ensure completeness
#
# Run Quality Checks

# %%
# Perform quality checks here

# %% [markdown]
# #### 4.3 Data dictionary
# Create a data dictionary for your data model. For each field, provide a brief description of what the data is and where it came from. You can include the data dictionary in the notebook or in a separate file.

# %% [markdown]
# #### Step 5: Complete Project Write Up
# * Clearly state the rationale for the choice of tools and technologies for the project.
# * Propose how often the data should be updated and why.
# * Write a description of how you would approach the problem differently under the following scenarios:
#  * The data was increased by 100x.
#  * The data populates a dashboard that must be updated on a daily basis by 7am every day.
#  * The database needed to be accessed by 100+ people.

# %%
def process_state_code_data(spark, output_data):
    """
    This function load data to S3
    """
    
    #create table
    state_code_table = spark.sql("""
                       SELECT
                       state_code,
                       state_name
                       FROM state_code_table
                       """)
    
    # write table to parquet files
    state_code_table.write.mode('overwrite').parquet(output_data+'state_code_table/')

# %%
def process_uscity_data(spark, output_data):
    """
    This function load data to S3
    """
    
    #create table
    uscity_table = spark.sql("""
                              SELECT
                              City as city_name,
                              'State Code' as state_code,
                              State as state_name,
                              'Median Age' as median_age,
                              'Male Population' as m_population,
                              'Female Population' as f_population,
                              'Total Population' as t_population,
                              'Number of Veterans' as veterans,
                              'Foreign-born' as foreign_born_population,
                              'Average Household Size' as avghousesize,
                              Race as race,
                              Count as count
                              FROM USCity_table_data
                              """)
    
    # write table to parquet files
    uscity_table.write.mode('overwrite').parquet(output_data+'uscity_table/')

# %%
city_code.write.csv("s3a://flaaffy-spark/test/")

# %%
# !curl http://169.254.169.254/

# %%
# !curl http://4.icanhazip.com/

# %%
import sys
sys.executable

# %%
from functools import reduce
reduce?

# %%
def union_dataframes(dfs):
    return reduce(
        lambda df1, df2: df1.union(df2), 
        dfs
    )

# %%
accural_alert_gleans.printSchema()
# Out:
# root
#  |-- glean_id: string (nullable = false)
#  |-- glean_date: string (nullable = true)
#  |-- glean_text: string (nullable = true)
#  |-- glean_type: string (nullable = false)
#  |-- glean_location: string (nullable = false)
#  |-- invoice_id: string (nullable = true)
#  |-- canonical_vendor_id: string (nullable = true)

# %%
vendor_not_seen_in_a_while_gleans.printSchema()
# Out:
# root
#  |-- glean_id: string (nullable = false)
#  |-- glean_date: string (nullable = true)
#  |-- glean_text: string (nullable = true)
#  |-- glean_type: string (nullable = false)
#  |-- glean_location: string (nullable = false)
#  |-- invoice_id: string (nullable = true)
#  |-- canonical_vendor_id: string (nullable = true)

# %%
combined_gleans = (
    accural_alert_gleans
    .union(vendor_not_seen_in_a_while_gleans)    
)
combined_gleans.printSchema()
# Out:
# root
#  |-- glean_id: string (nullable = false)
#  |-- glean_date: string (nullable = true)
#  |-- glean_text: string (nullable = true)
#  |-- glean_type: string (nullable = false)
#  |-- glean_location: string (nullable = false)
#  |-- invoice_id: string (nullable = true)
#  |-- canonical_vendor_id: string (nullable = true)

# %%
combined_gleans.count()
# Out:
# 302

# %%
combined_gleans = union_dataframes([
    accural_alert_gleans,
    vendor_not_seen_in_a_while_gleans
]).count()
# Out:
# 302
